# %% [markdown]
# # 🙌🏾 Murakaza Neza !
# ### Welcome to this tutorial for the 2025 Kinyarwanda Automatic Speech Recognition Track A Challenge !
#
# Competition page: https://www.kaggle.com/competitions/kinyarwanda-automatic-speech-recognition-track-a

# %%
# !gdown 1S2NOhJq6NoDOxzVBUs1436hFuB5JSUeS

# %%
# !tar -xzf /kaggle/working/subset_audio_train.tar.gz -C ./audio_dat
# Out:
# tar: audio_dat: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
# !mkdir -p ./audio_dat && tar -xzf /kaggle/working/subset_audio_train.tar.gz -C ./audio_dat

# %%
# for f in audio_data:
#     try:
#         os.remove(f[2:])
#     except:
#         print("failed")
    
# # print(f"Deleted {len(wav_files)} .wav files.")
# Out:
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed

# %% [markdown]
# This is a simple tutorial for leveraging the preprocessed dataset [kinasr2025-track-a-melspec](https://www.kaggle.com/datasets/cedricmanouan11/kinasr2025-track-a-melspec) that shares extracted mel spectrograms to build  ASR models for the `Kinyarwanda Automatic Speech Recognition Track A Challenge`.
# You can check the `spec_params` variables below to see the parameters used to generate the log mel spectrograms.
#
# Key featurers:
# * ✅ Dataset class
# * ✅ Data module class (for later integration with [(Pytorch) Lightning](https://lightning.ai/docs/pytorch/stable/starter/introduction.html))
# * ✅ Simple character-based tokenizer
# * ✅ Data visualization + EDA utility functions
# * ✅ An example config class

# %%
# !pip install -q --no-cache-dir nemo_toolkit['all']
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 266.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 220.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.1/74.1 kB 284.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 234.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 59.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 317.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 308.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.9/175.9 kB 326.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 325.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 349.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 301.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 324.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 346.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 321.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 289.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 851.4/851.4 kB 352.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 349.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 220.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.2/658.2 kB 330.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.4/441.4 kB 5.9 MB/s eta 0:00:00a 0:00:010m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.8/17.8 MB 232.8 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 267.9 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 58.2 MB/s eta 0:00:0000:0100:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 101.4 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 119.3 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 65.0 MB/s eta 0:00:0000:0100:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 295.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.3/211.3 kB 302.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 65.7 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 74.6 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 244.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.8/419.8 kB 199.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 225.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.5 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.0/135.0 kB 317.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 228.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 78.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 76.6 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 76.1 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 315.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 74.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.1/185.1 kB 323.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 284.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 MB 82.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 214.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 255.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 179.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 94.1 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 96.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 291.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 245.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 231.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 268.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.7/711.7 kB 96.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 287.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.3/94.3 kB 294.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 92.3 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.9/171.9 kB 298.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 101.2 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 253.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 246.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 283.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 101.9 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 53.3 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 160.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 57.4 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 267.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 283.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.8/195.8 kB 283.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.4/100.4 kB 285.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.8 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.5/585.5 kB 64.7 MB/s eta 0:00:00
#   Building wheel for cdifflib (pyproject.toml) ... done
#   Building wheel for sox (setup.py) ... done
#   Building wheel for texterrors (setup.py) ... done
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done
#   Building wheel for rouge_score (setup.py) ... done
#   Building wheel for intervaltree (setup.py) ... done
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#     WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 25.2.0 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.0 which is incompatible.
# cuml-cu12 25.2.1 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.0 which is incompatible.
# cudf-cu12 25.2.2 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.0 which is incompatible.
# distributed-ucxx-cu12 0.42.0 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.0 which is incompatible.
# ypy-websocket 0.8.4 requires aiofiles<23,>=22.1.0, but you have aiofiles 24.1.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.

# %%
# ! python -m pip install lightning -qqq
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 22.8 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 363.4/363.4 MB 210.4 MB/s eta 0:00:01^C:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 363.4/363.4 MB 210.4 MB/s eta 0:00:01

# %%
# !export HUGGINGFACE_HUB_TOKEN=
# !source ~/.bashrc

# %%
import os
os.environ["HUGGINGFACE_HUB_TOKEN"] = "<your environment_variable_token>"
from huggingface_hub import hf_hub_download

# Will automatically use the token
model_path = hf_hub_download(repo_id="mbazaNLP/Kinyarwanda_nemo_stt_conformer_model", filename="Kinyarwanda_nemo_stt_conformer_model.nemo")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 os.environ["HUGGINGFACE_HUB_TOKEN"] = "<your environment_variable_token>"
# ----> 3 from huggingface_hub import hf_hub_download
#       5 # Will automatically use the token
#       6 model_path = hf_hub_download(repo_id="mbazaNLP/Kinyarwanda_nemo_stt_conformer_model", filename="Kinyarwanda_nemo_stt_conformer_model.nemo")
#
# ModuleNotFoundError: No module named 'huggingface_hub'

# %%
# !echo "hf" | huggingface-cli login --token hf
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Traceback (most recent call last):
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_http.py", line 406, in hf_raise_for_status
#     response.raise_for_status()
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/whoami-v2
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\hf_api.py", line 1670, in whoami
#     hf_raise_for_status(r)
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_http.py", line 477, in hf_raise_for_status
#     raise _format(HfHubHTTPError, str(e), response) from e
# huggingface_hub.errors.HfHubHTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/whoami-v2 (Request ID: Root=1-68c1ce99-2b5d396c2489e3740f7db44d;020ef066-a396-4bf0-b4d3-3d9c62ce9466)
#
# Invalid credentials in Authorization header
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Scripts\huggingface-cli.exe\__main__.py", line 7, in <module>
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\commands\huggingface_cli.py", line 57, in main
#     service.run()
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\commands\user.py", line 153, in run
#     login(
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\_login.py", line 119, in login
#     _login(token, add_to_git_credential=add_to_git_credential, write_permission=write_permission)
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\_login.py", line 397, in _login
#     token_info = whoami(token)
#                  ^^^^^^^^^^^^^
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\STUDENT\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\hf_api.py", line 1672, in whoami
#     raise HTTPError(
# requests.exceptions.HTTPError: Invalid user token. If you didn't pass a user token, make sure you are properly logged in by executing `huggingface-cli login`, and if you did pass a user token, double-check it's correct.

# %%
import nemo.collections.asr as nemo_asr
# asr_model = nemo_asr.models.EncDecCTCModelBPE.from_pretrained("nvidia/stt_rw_conformer_ctc_large")
asr_model = nemo_asr.models.ASRModel.from_pretrained("mbazaNLP/Kinyarwanda_nemo_stt_conformer_model")
# Out:
# (…)inyarwanda_nemo_stt_conformer_model.nemo:   0%|          | 0.00/489M [00:00<?, ?B/s]
# [NeMo I 2025-06-11 14:04:09 nemo_logging:393] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2025-06-11 14:04:09 nemo_logging:405] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /data/chanie/asr/manifest/train_tarred_1bk/tarred_audio_manifest.json
#     sample_rate: 16000
#     batch_size: 32
#     shuffle: true
#     num_workers: 4
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 16.7
#     min_duration: 0.1
#     is_tarred: true
#     tarred_audio_filepaths: /data/chanie/asr/manifest/train_tarred_1bk/audio__OP_0..1023_CL_.tar
#     shuffle_n: 2048
#     bucketing_strategy: synced_randomized
#     bucketing_batch_size: null
#
# [NeMo W 2025-06-11 14:04:09 nemo_logging:405] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /data/chanie/asr/manifest/dev_manifest_clean_decoded.json
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 4
#     pin_memory: true
#     use_start_end_token: false
#
# [NeMo W 2025-06-11 14:04:09 nemo_logging:405] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: /data/chanie/asr/manifest/test_manifest_clean_decoded.json
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 4
#     pin_memory: true
#     use_start_end_token: false
# [NeMo I 2025-06-11 14:04:09 nemo_logging:393] PADDING: 0
# [NeMo I 2025-06-11 14:04:11 nemo_logging:393] Model EncDecCTCModelBPE was successfully restored from /root/.cache/huggingface/hub/models--mbazaNLP--Kinyarwanda_nemo_stt_conformer_model/snapshots/6a95dc2c0015c9fb40d90e96bec55e7566a43f2c/Kinyarwanda_nemo_stt_conformer_model.nemo.

# %%
import glob

# %%
audio_data = glob.glob("./audio_dat/*.wav")
len(audio_data)
# Out:
# 10000

# %%
outputs = asr_model.transcribe(audio_data)
print(outputs[0].text)

"Biragaragara ko ari umugabo wambaye impuzankano z'ubushinjacyaha, ashinzwe mu kunga abaturage mu gukemura ibibazo byabo baba bagiranye."
# Out:
# Transcribing: 100%|██████████| 2500/2500 [08:46<00:00,  4.75it/s]
# umuhanda ucamo ibinyabiziga bigiye bitandukanye hakaba harimo haracamo moto kurande hari utuyira tw'abanyamaguru ndetse akaba ariteye n'ubusitani crandles y'utwo tuyira hirya y'umuhanda hari ubusitani buteyemo ibiti birebire kandi byinshi hari n'amapoto asakaza amashanyarazi ndetse anamurikira abantu mu gihe cy'ijoro
# "Biragaragara ko ari umugabo wambaye impuzankano z'ubushinjacyaha, ashinzwe mu kunga abaturage mu gukemura ibibazo byabo baba bagiranye."

# %%
len(outputs)
# Out:
# 2369

# %%
import difflib

def calculate_wer(ref: str, hyp: str) -> float:
    """Calculate Word Error Rate (WER)."""
    ref_words = ref.strip().split()
    hyp_words = hyp.strip().split()
    sm = difflib.SequenceMatcher(None, ref_words, hyp_words)
    edits = sum(max(i2 - i1, j2 - j1) for tag, i1, i2, j1, j2 in sm.get_opcodes() if tag != 'equal')
    return edits / len(ref_words) if ref_words else 0.0

def calculate_cer(ref: str, hyp: str) -> float:
    """Calculate Character Error Rate (CER)."""
    ref_chars = list(ref.strip())
    hyp_chars = list(hyp.strip())
    sm = difflib.SequenceMatcher(None, ref_chars, hyp_chars)
    edits = sum(max(i2 - i1, j2 - j1) for tag, i1, i2, j1, j2 in sm.get_opcodes() if tag != 'equal')
    return edits / len(ref_chars) if ref_chars else 0.0

def calculate_asr_score(ref: str, hyp: str) -> dict:

    wer = calculate_wer(ref, hyp)
    cer = calculate_cer(ref, hyp)
    combined_error = 0.4 * wer + 0.6 * cer
    score = (1 - combined_error) * 100
    return {'WER': wer, 'CER': cer, 'Score': score}
ref = "the quick brown fox jumps over the lazy dog"
hyp = "the quick brown fox jump over a lazy dog"
result = calculate_asr_score(ref, hyp)

print(f"WER: {result['WER']:.2%}")
print(f"CER: {result['CER']:.2%}")
print(f"Score: {result['Score']:.2f}")
# Out:
# WER: 22.22%
# CER: 9.30%
# Score: 85.53

# %%
# Extract file names without extension
import os
file_names = [os.path.splitext(os.path.basename(f))[0] for f in audio_data]

# %%
results = []
for output, file in zip(outputs, file_names):
    ref = train_df[train_df["audio_path"]== f'audio/{file}'].transcription[0]
    hyp = output.text
    result = calculate_asr_score(ref, hyp)
    result["file"] = file
    result['hyp'] = hyp
    result['ref'] = ref
    results.append(result
                  )

# %%
df = pd.DataFrame(results)

# %%
 df['Score'] = df['Score'].clip(lower=0)

# %%
df
# Out:
#            WER       CER      Score                                     file  \
# 0     0.324324  0.391720  63.523842  1739484408-NjR5zndWxvcCeU4vp5pQkhHd2xx1
# 1     0.272727  0.083045  84.108210  1743017391-Gqwduv56N2Xnb1Cv61DdkPUTok72
# 2     0.176471  0.022222  91.607843  1739043777-Ftf292mUi3QZ4MuwS7DnIkwlLA72
# 3     0.647059  0.354167  52.867647  1740064299-YpCB8JDRwCV3I8OKa7H0Hg79WIT2
# 4     0.235294  0.097656  84.728860  1739529879-OogTF7X5UsTPNsR9q4GLZYcJiKB2
# ...        ...       ...        ...                                      ...
# 9995  0.190476  0.047059  89.557423  1740307276-C3kE24gBxDeuFec9tmR993N9wCb2
# 9996  0.250000  0.037383  87.757009  1739026480-HGfDmV2FbaZ8vJ8tPyT1i5HSUUk1
# 9997  0.533333  0.372807  56.298246  1740131230-KrNwrUSz6cb9wY8jP3phHDEPCO73
# 9998  0.500000  0.052239  76.865672  1737132677-edDS7WSeKCS6O2zFNySBoWwMtpX2
# 9999  0.250000  0.036364  87.818182  1742334607-bJOqNTv2sXelPEW1C5QXZ59kUf23
#
#                                                     hyp  \
# 0     umuhanda ucamo ibinyabiziga bigiye bitandukany...
# 1     ibikoresho byinshi cyane bitandukanye byifashi...
# 2     biragaragara ko ari umugabo wambaye impuzankan...
# 3     icyapa cyamamaza iki cyapa cya rwanda revenue ...
# 4     imodoka ifite umwanya w'inyuma ujya kumera nk'...
# ...                                                 ...
# 9995  iduka ritangirwamo serivisi zo kuvunja amafara...
# 9996  ibyatsi biteye imbere y'igipangu cyubakishije ...
# 9997  abantu bicaye bari mu nama bakwambaye imipira ...
# 9998  utubari twose twashyiriweho ingamba ko tugomba...
# 9999  icyatsi cy'amababi magufi menshi cyera gihagaz...
#
#                                                     ref
# 0     Umuhanda ucamo ibinyabiziga bigiye bitandukany...
# 1     Ibikoresho byinshi cyane bitandukanye, byifash...
# 2     Biragaragara ko ari umugabo wambaye impuzankan...
# 3     Icyapa cyamamaza. Iki cyapa ni icya Rwanda Rev...
# 4     Imodoka ifite umwanya w'inyuma ujya kumera nk'...
# ...                                                 ...
# 9995  Iduka ritangirwamo serivisi zo kuvunja amafara...
# 9996  Ibyatsi biteye imbere y'igipangu cyubakishije ...
# 9997  Abantu bicaye bari mu nama bakaba bambaye imip...
# 9998  Utubari twose twashyiriyeho ingamba ko tugomba...
# 9999  Icyatsi cy'amababi magufi menshi, cyera gihaga...
#
# [10000 rows x 6 columns]

# %%
df.Score.median()
# Out:
# 92.19971264367817

# %%
# df.to_csv("results.csv")

# %%
df.WER.median()
# Out:
# 0.12

# %%
df
# Out:
#            WER       CER      Score                                     file  \
# 0     0.235294  0.037037  88.366013  1739043777-Ftf292mUi3QZ4MuwS7DnIkwlLA72
# 1     0.307692  0.074286  83.235165  1738695647-6HzF9fovs6We1DF3IiefDmYUMV13
# 2     0.166667  0.035461  91.205674  1739046064-mAlBLvrb1Rfg0BL4IEu1wPfumQG3
# 3     0.421053  0.059259  79.602339  1738821458-R5RKoYXsHMWKFT0iPTdn49z13Sp1
# 4     0.444444  0.326829  62.612466  1738240365-irDWrRCzatdYvSxQT4UIpnBoccS2
# ...        ...       ...        ...                                      ...
# 2364  0.384615  0.146341  75.834897  1737234136-kDAvFAY9i5UwKS0FP86XvpAyg2F3
# 2365  0.260870  0.068182  85.474308  1737323959-D1mvHhECX5ZYhJiGDqOOiN4hxWs2
# 2366  0.363636  0.052632  82.296651  1739134699-4fHgxq3nEKebOfrQFyC9pITmSrF3
# 2367  0.250000  0.037383  87.757009  1739026480-HGfDmV2FbaZ8vJ8tPyT1i5HSUUk1
# 2368  0.500000  0.052239  76.865672  1737132677-edDS7WSeKCS6O2zFNySBoWwMtpX2
#
#                                                     hyp  \
# 0     biragaragara ko ari umugabo wambaye impuzankan...
# 1     amazu meza cyane maremare yubatse mu mujyi har...
# 2     iki n'icyapa kirimo ibara ry'umutuku ndetse n'...
# 3     umuhanda urimo ibinyabiziga bigiye bitandukany...
# 4     umuhanzi kizito yambaye ishati y'iroza arimo a...
# ...                                                 ...
# 2364  aha ni umucuruzi w'ikigo cy'umuyoboro wa mt ah...
# 2365  aha ni ahantu habugenewe hacururizwa amata y'i...
# 2366  iduka ririmo ibicuruzwa bitandukanye bimwe bir...
# 2367  ibyatsi biteye imbere y'igipangu cyubakishije ...
# 2368  utubari twose twashyiriweho ingamba ko tugomba...
#
#                                                     ref
# 0     Biragaragara ko ari umugabo wambaye impuzankan...
# 1     Amazu meza cyane maremare yubatse mu mugi. Har...
# 2     Iki n'icyapa kirimo ibara ry'umutuku ndetse n'...
# 3     Umuhanda urimo ibinyabiziga bigiye bitandukany...
# 4     Umuhazni Kizito yambaye ishati y'iroza. Arimo ...
# ...                                                 ...
# 2364  Aha ni umucuruzi w'ikigo cy'igihugu cy'umuyobo...
# 2365  Aha ni ahantu habugenewe hacururizwa amata y'i...
# 2366  Iduka ririmo ibicuruzwa bitandukanye bimwe bir...
# 2367  Ibyatsi biteye imbere y'igipangu cyubakishije ...
# 2368  Utubari twose twashyiriyeho ingamba ko tugomba...
#
# [2369 rows x 6 columns]

# %%
import pandas as pd
import string
import difflib

# Assuming your DataFrame is called `df`

def clean_text(text):
    # Remove punctuation and lowercase the text
    text = text.lower()
    return text.translate(str.maketrans('', '', string.punctuation))

def calculate_wer(ref: str, hyp: str) -> float:
    ref_words = ref.strip().split()
    hyp_words = hyp.strip().split()
    sm = difflib.SequenceMatcher(None, ref_words, hyp_words)
    edits = sum(max(i2 - i1, j2 - j1) for tag, i1, i2, j1, j2 in sm.get_opcodes() if tag != 'equal')
    return edits / len(ref_words) if ref_words else 0.0

def calculate_cer(ref: str, hyp: str) -> float:
    ref_chars = list(ref.strip())
    hyp_chars = list(hyp.strip())
    sm = difflib.SequenceMatcher(None, ref_chars, hyp_chars)
    edits = sum(max(i2 - i1, j2 - j1) for tag, i1, i2, j1, j2 in sm.get_opcodes() if tag != 'equal')
    return edits / len(ref_chars) if ref_chars else 0.0

def calculate_score(row):
    wer = calculate_wer(row['ref_clean'], row['hyp_clean'])
    cer = calculate_cer(row['ref_clean'], row['hyp_clean'])
    score = (1 - (0.4 * wer + 0.6 * cer)) * 100
    return pd.Series({'WER': wer, 'CER': cer, 'Score': score})

# Clean the columns
df['ref_clean'] = df['ref'].apply(clean_text)
df['hyp_clean'] = df['hyp'].apply(clean_text)

# Recalculate scores
df[['WER', 'CER', 'Score']] = df.apply(calculate_score, axis=1)

# Optionally drop the clean columns if you no longer need them
# df.drop(columns=['ref_clean', 'hyp_clean'], inplace=True)

# Preview
print(df[['WER', 'CER', 'Score', 'file']].head())
# Out:
#         WER       CER       Score                                     file
# 0  0.135135  0.168874   84.462144  1739484408-NjR5zndWxvcCeU4vp5pQkhHd2xx1
# 1  0.000000  0.000000  100.000000  1743017391-Gqwduv56N2Xnb1Cv61DdkPUTok72
# 2  0.000000  0.000000  100.000000  1739043777-Ftf292mUi3QZ4MuwS7DnIkwlLA72
# 3  0.323529  0.066372   83.076523  1740064299-YpCB8JDRwCV3I8OKa7H0Hg79WIT2
# 4  0.117647  0.084337   90.233877  1739529879-OogTF7X5UsTPNsR9q4GLZYcJiKB2

# %%
labled = [*zip(output, file_names)]

# %%
import inspect

print(inspect.signature(output[0]))

# %%
output[0]
# Out:
# Hypothesis(score=tensor(-2.4214), y_sequence=tensor([  5, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 102, 128, 128, 128,   6, 128, 128, 128,  14, 128,
#         128,   6,   6, 128, 128,  14, 128, 128, 128,   6, 128, 128,   4, 108,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128,   8, 128, 128, 128,   9, 128, 128, 128,  10, 128, 128,   7,
#         128, 128, 128,  14, 128, 128, 128, 128,  32, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 100, 128,  16, 128, 128, 128, 128,
#         109, 128,  12, 128, 128, 128,  13, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128,   3, 128, 128, 128, 128, 109, 128,
#         124, 103, 103, 103, 128, 128, 128, 117, 128, 128,   1,   1, 128, 110,
#         128, 128,   1, 128, 108, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 100,
#         117, 128, 120, 120, 103, 128,  38, 128, 128, 128,  15,  15,  23, 128,
#         128, 128, 128, 121, 101, 101, 128, 128, 128, 119, 128,  11, 128, 128,
#         128, 128, 128, 128, 128,  37, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128,   8, 128, 128, 128, 128, 128,  15,  23,
#         128, 128, 128, 128, 128, 117, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         100, 128,   7, 128, 128, 128,   4, 103, 128, 128, 128, 128, 128, 128,
#         128, 105, 128, 128,  14, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128,   8, 128, 128, 128,  12, 128,
#         128, 128, 128,  30, 128, 128, 128, 128,   6, 128, 128, 128, 128,  33,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#         128, 100,   7, 128, 128, 100,  26, 128, 128, 128,  62, 128, 128, 128,
#         128,   7, 128, 128, 128,   6, 128, 128, 128, 128, 128, 128,   3, 128,
#         128,  29, 128, 128, 128,  12, 128, 128, 128,  69, 128, 128,   5, 128,
#          11, 128, 128, 128, 128, 128, 128, 128,  32, 128, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,   5, 128,
#         101, 128, 128,  12, 128, 128,   5, 128, 101, 128, 128, 128, 128,  21,
#         128, 128, 128, 128, 106, 128,   1,   1, 128,  13, 128, 128, 128, 128,
#         128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]), text="biragaragara ko ari umugabo wambaye impuzankano z'ubushinjacyaha ashinz mu kunga abaturage mu gukemura ibibazo byabo baba bagiranye", dec_out=None, dec_state=None, timestamp=[], alignments=None, frame_confidence=None, token_confidence=None, word_confidence=None, length=0, y=None, lm_state=None, lm_scores=None, ngram_lm_state=None, tokens=None, last_token=None, token_duration=None, last_frame=None)

# %%
import IPython.display as ipd

audio_file = "output.wav"
ipd.Audio(audio_file)

# %%
glob.glob("./*.json")
# Out:
# []

# %%
# Extract file names without extension
import os
file_names = [os.path.splitext(os.path.basename(f))[0] for f in audio_data]

# %%
len(file_names)
# Out:
# 2369

# %%
audio_data[0]
# Out:
# './1739043777-Ftf292mUi3QZ4MuwS7DnIkwlLA72.wav'

# %%
train = './train.json'

import pandas as pd

train_json_path = train
train_df = pd.read_json(train_json_path).T
train_df.head()
# Out:
#                                   voice_creator_id  \
# AYGBpezo9OcAS9jyjVWh  GGV0DaVftpfbL7qn1EbCrqXamdk2
# K0sLwAQgpkcHQl2F5obe  9Q9RG8PhUva4tKnFqMCjM7796NG3
# 51C4wMfUX65ZsZEPfHd5  8iuTHK211mZUp2P9r7miF3z2gim2
# VlDZXO36HpGXEksYc1TC  3rpI92hNvMeUPS94jrXox5ckIfv1
# HzNzAFS0eYvp7MWNT65v  wW06tLmeRmTnt6ikhChglQxMYzt2
#
#                                                image_path      image_category  \
# AYGBpezo9OcAS9jyjVWh  image/PXL_20241204_104642770.MP.jpg  Financial Services
# K0sLwAQgpkcHQl2F5obe                image/IMG_CD (17).jpg  Financial Services
# 51C4wMfUX65ZsZEPfHd5            image/20230714_124252.jpg  Financial Services
# VlDZXO36HpGXEksYc1TC     image/PXL_20241231_082724650.jpg  Financial Services
# HzNzAFS0eYvp7MWNT65v     image/PXL_20241208_145401981.jpg  Financial Services
#
#                        image_sub_category  \
# AYGBpezo9OcAS9jyjVWh       Shopping malls
# K0sLwAQgpkcHQl2F5obe      Car dealerships
# 51C4wMfUX65ZsZEPfHd5                 Bars
# VlDZXO36HpGXEksYc1TC  Dairy product shops
# HzNzAFS0eYvp7MWNT65v  Dairy_product_shops
#
#                                                          audio_path  \
# AYGBpezo9OcAS9jyjVWh  audio/1738095369-GGV0DaVftpfbL7qn1EbCrqXamdk2
# K0sLwAQgpkcHQl2F5obe  audio/1738827604-9Q9RG8PhUva4tKnFqMCjM7796NG3
# 51C4wMfUX65ZsZEPfHd5  audio/1736949094-8iuTHK211mZUp2P9r7miF3z2gim2
# VlDZXO36HpGXEksYc1TC  audio/1739374527-3rpI92hNvMeUPS94jrXox5ckIfv1
# HzNzAFS0eYvp7MWNT65v  audio/1737690377-wW06tLmeRmTnt6ikhChglQxMYzt2
#
#                                                           transcription  \
# AYGBpezo9OcAS9jyjVWh  Urenze umuhanda munini n'agahanda k'abanyamagu...
# K0sLwAQgpkcHQl2F5obe  Ahangaha hari ikinyabiziga cyiza cyane gifite ...
# 51C4wMfUX65ZsZEPfHd5  Mu ma bari, amaresitora, amahoteri byo mu Rwan...
# VlDZXO36HpGXEksYc1TC  Iduka rikora ibijyanye ndetse n'ibikomoka ku m...
# HzNzAFS0eYvp7MWNT65v  Ahantu bacururiza amata ndetse bagacuruza n'ib...
#
#                      age_group  gender     project_name locale  year duration  \
# AYGBpezo9OcAS9jyjVWh     36-49  Female  KINYARWANDA2025  rw_RW  2025     20.4
# K0sLwAQgpkcHQl2F5obe     18-24  Female  KINYARWANDA2025  rw_RW  2025    24.84
# 51C4wMfUX65ZsZEPfHd5     18-24    Male  KINYARWANDA2025  rw_RW  2025    28.92
# VlDZXO36HpGXEksYc1TC     18-24  Female  KINYARWANDA2025  rw_RW  2025    17.52
# HzNzAFS0eYvp7MWNT65v     18-24    Male  KINYARWANDA2025  rw_RW  2025    15.36
#
#                      location
# AYGBpezo9OcAS9jyjVWh     None
# K0sLwAQgpkcHQl2F5obe     None
# 51C4wMfUX65ZsZEPfHd5     None
# VlDZXO36HpGXEksYc1TC     None
# HzNzAFS0eYvp7MWNT65v     None

# %%
labled[80]
# Out:
# (Hypothesis(score=tensor(-12.1983), y_sequence=tensor([ 10, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,  28,  28,
#          128, 128,  82, 128, 128, 124, 103, 128, 128, 128,  48, 128, 128, 128,
#          128, 128, 128, 128,   2, 128, 128, 128, 128,  23, 128, 128,  35, 128,
#          128, 128,  59, 128, 128, 128, 128,  22, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128,   5, 128, 128,  42, 128, 128, 128, 128, 128,  15,
#          103, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128,  10, 128, 128, 128, 128, 128, 128,  38, 128, 128,
#          128,   7, 128, 128, 105,  30, 128, 128, 128, 128, 128, 128, 128, 128,
#          128,   8, 128, 128, 128, 128,  18, 128, 128, 128,  36, 128, 128, 128,
#          128,   4, 128, 103, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128,  19, 128, 128, 128,  17,
#          128,  22, 128, 128,   8,  18, 128, 128,  68, 128, 128, 106, 106, 128,
#            1,  14, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 100,   7,
#          128, 128, 100,  18, 128, 128, 128, 115, 128, 128, 128,   1, 128, 128,
#           14, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128,   5, 128, 101, 128, 128,  35, 128, 128, 128, 128,  27, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128,  46, 128, 128, 128,
#          128, 128, 128,   1, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 100, 128, 112, 128, 128,   6, 128,
#          128, 128, 128, 109, 128,  94, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128,
#          128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]), text='urupapuro ninyimiza bwishu ubumuntu amaze kukoreza amafaranga mu mahanga bayita man grammb', dec_out=None, dec_state=None, timestamp=[], alignments=None, frame_confidence=None, token_confidence=None, word_confidence=None, length=0, y=None, lm_state=None, lm_scores=None, ngram_lm_state=None, tokens=None, last_token=None, token_duration=None, last_frame=None),
#  '1738272505-Q5ugPPAj1icgiHSOhSnEStZkoYl2')

# %%
train_df[train_df["audio_path"]== 'audio/1738272505-Q5ugPPAj1icgiHSOhSnEStZkoYl2'].transcription[0]
# Out:
# 'Urupapuro ni inyemeza bwishyu ko umuntu amaze kohereza amafaranga mu mahanga bayita mani garame.'

# %%
import IPython.display as ipd

audio_file = "1738272505-Q5ugPPAj1icgiHSOhSnEStZkoYl2.wav"
ipd.Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 📚 Importing the necessary libraries

# %%
import matplotlib.pyplot as plt

import numpy as np

import os
import os.path as osp

import pandas as pd
from pathlib import Path

# import lightning
# import lightning.pytorch as pl

import seaborn as sns
import sys
import string

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchaudio
import torchaudio.transforms as T

import warnings
warnings.filterwarnings("ignore")

# %%
print(f"{torch.__version__=}")
print(f"{torchaudio.__version__=}")
print(f"{lightning.__version__=}")
print(f"{np.__version__=}")
print(f"{pd.__version__=}")
# Out:
# torch.__version__='2.6.0+cu124'
# torchaudio.__version__='2.6.0+cu124'
# lightning.__version__='2.5.1.post0'
# np.__version__='1.26.4'
# pd.__version__='2.2.3'

# %% [markdown]
# # ⚙️ Config

# %%
config_dict = {
    "paths":{
        "data_path": "/kaggle/input/kinasr2025-track-a-melspec/track_A_audio",
        "preprocessed_path": "/kaggle/input/kinasr2025-track-a-melspec/preprocessed_track_a/preprocessed",
        "features_path": "/kaggle/input/kinasr2025-track-a-melspec/preprocessed_track_a/preprocessed/features"
    },
    "data_pct": 15.,
    "seed": 123,
    "spec_params": {
        "feature_type": "melspec",  # "melspec", "mfcc", or "fbank"
        "sr": 16000,
        "n_feats": 128,
        "specaug_rate": 0.3,
        "time_mask": 30,
        "freq_mask": 5,
        "win_length": 512,
        "n_fft": 2048,
        "n_mels": 128,
        "n_mfcc": 40,
        "f_min": 50.0,
        "f_max": 15000,
        "top_db": 80,
        "power": 2.0    
    },
    "min_len": 10,
    "max_len": 256,
    "max_trim_audio": 30,
    "num_workers": os.cpu_count(),
    "training": {
        "batch_size": 8
    }

}

class DotDict:
    def __init__(self, d):
        for k, v in d.items():
            if isinstance(v, dict):
                v = DotDict(v)
            setattr(self, k, v)

    def __getitem__(self, key):
        return getattr(self, key)

class Config:
    def __init__(self, d:dict=config_dict):
        self.config_dict = d
        self.__dict__.update(DotDict(self.config_dict).__dict__)


cfg = Config()
cfg.spec_params.sr, cfg.spec_params.feature_type, cfg.paths.preprocessed_path
# Out:
# (16000,
#  'melspec',
#  '/kaggle/input/kinasr2025-track-a-melspec/preprocessed_track_a/preprocessed')

# %% [markdown]
# # 🏷️ Tokenizer
#
# We keep it simple and use a character-based tokenizer that handles both `encoding` and `decoding` of the audio transcripts.

# %%
class CharTokenizer:
    def __init__(self, vocab_path:str="vocab.json"):
        try:
            with open(vocab_path, "r", encoding="utf-8") as f:
                self.vocab = json.load(f)
            self.char2idx = self.vocab["char2idx"]
            self.idx2char = {int(k): v for k, v in self.vocab["idx2char"].items()}
        except Exception as e:
            base_chars = list(string.ascii_lowercase + string.digits + string.punctuation + " ")
            # Special tokens
            special_tokens = ["<|pad|>", "<|sos|>", "<|eos|>", "<|unk|>"]
            self.vocab = special_tokens + base_chars
            
            # Build mappings
            self.char2idx = {char: idx for idx, char in enumerate(self.vocab)}
            self.idx2char = {int(idx): char for char, idx in self.char2idx.items()}
        
        
        self.pad_idx = self.char2idx["<|pad|>"]
        self.sos_idx = self.char2idx["<|sos|>"]
        self.eos_idx = self.char2idx["<|eos|>"]
        self.unk_idx = self.char2idx["<|unk|>"]

    def encode(self, text, max_len=None):
        tokens = [self.char2idx.get(c, self.unk_idx) for c in text.lower()]
        tokens = [self.sos_idx] + tokens + [self.eos_idx]
        if max_len:
            tokens = tokens[:max_len] + [self.pad_idx] * max(0, max_len - len(tokens))
        return tokens

    def encode_batch(self, texts, max_len=None):
        return [self.encode(t, max_len) for t in texts]

    def decode(self, ids, skip_special=True):
        return "".join(
            [self.idx2char.get(i, "") for i in ids
             if not skip_special or i not in {self.pad_idx, self.sos_idx, self.eos_idx, self.unk_idx}]
        )

    def decode_batch(self, batch_ids, skip_special=True):
        return [self.decode(ids, skip_special) for ids in batch_ids]

    def vocab_size(self):
        return len(self.char2idx)

# %%
tokenizer = CharTokenizer()
tokenizer.vocab[:10]
# Out:
# ['<|pad|>', '<|sos|>', '<|eos|>', '<|unk|>', 'a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# # 🗂️ Load data files

# %% [markdown]
# These dataframes were generated based on the original `.json` files provided by the organizers.
# We are only using this data format by choice and for easy manipulation.
#
# `tokens` here refer to atomic symbols extracted from sentence with `space` as separator.

# %%
train  = pd.read_csv(osp.join(cfg.paths.preprocessed_path, "train.csv"))
dev    = pd.read_csv(osp.join(cfg.paths.preprocessed_path, "dev_test.csv"))
test   = pd.read_csv(osp.join(cfg.paths.preprocessed_path, "test.csv"))

train.shape, dev.shape, test.shape
# Out:
# ((90163, 16), (4632, 16), (4634, 14))

# %%
train.head(n=2)
# Out:
#                      id              voice_creator_id  \
# 0  AYGBpezo9OcAS9jyjVWh  GGV0DaVftpfbL7qn1EbCrqXamdk2
# 1  K0sLwAQgpkcHQl2F5obe  9Q9RG8PhUva4tKnFqMCjM7796NG3
#
#                             image_path      image_category image_sub_category  \
# 0  image/PXL_20241204_104642770.MP.jpg  Financial Services     Shopping malls
# 1                image/IMG_CD (17).jpg  Financial Services    Car dealerships
#
#                                       audio_path  \
# 0  audio/1738095369-GGV0DaVftpfbL7qn1EbCrqXamdk2
# 1  audio/1738827604-9Q9RG8PhUva4tKnFqMCjM7796NG3
#
#                                        transcription age_group  gender  \
# 0  Urenze umuhanda munini n'agahanda k'abanyamagu...     36-49  Female
# 1  Ahangaha hari ikinyabiziga cyiza cyane gifite ...     18-24  Female
#
#       project_name locale  year  duration location  sentence_length  \
# 0  KINYARWANDA2025  rw_RW  2025     20.40      NaN              173
# 1  KINYARWANDA2025  rw_RW  2025     24.84      NaN              310
#
#    num_tokens
# 0          22
# 1          41

# %%
dev.head(n=1)
# Out:
#                      id              voice_creator_id  \
# 0  BFzbR5Ls9FXwrzMRmcIi  OogTF7X5UsTPNsR9q4GLZYcJiKB2
#
#                  image_path      image_category   image_sub_category  \
# 0  image/2020-06-05 (1).jpg  Financial Services  Dairy product shops
#
#                                       audio_path  \
# 0  audio/1739532284-OogTF7X5UsTPNsR9q4GLZYcJiKB2
#
#                                        transcription age_group gender  \
# 0  Akajerekani gateretse hasi ku butaka gapfundik...     18-24   Male
#
#       project_name locale  year  duration location  sentence_length  \
# 0  KINYARWANDA2025  rw_RW  2025     16.26      NaN              142
#
#    num_tokens
# 0          16

# %%
test.head(n=2)
# Out:
#                      id              voice_creator_id  \
# 0  gbs7Mf2cCuKq71qDKmiJ  NQH9ahEaFMau4SYWUphSbr04prt2
# 1  Q02in6O5RFJc9Fyh9zY3  8iuTHK211mZUp2P9r7miF3z2gim2
#
#                            image_path      image_category  \
# 0  image/MTN-Rwanda-norvanreports.jpg  Financial Services
# 1       image/IMG-20241225-WA0008.jpg  Financial Services
#
#     image_sub_category                                     audio_path  \
# 0  Mobile money kiosks  audio/1739736289-NQH9ahEaFMau4SYWUphSbr04prt2
# 1  Dairy_product_shops  audio/1736929024-8iuTHK211mZUp2P9r7miF3z2gim2
#
#    transcription age_group gender     project_name locale  year  duration  \
# 0            NaN     25-35   Male  KINYARWANDA2025  rw_RW  2025     17.16
# 1            NaN     18-24   Male  KINYARWANDA2025  rw_RW  2025     19.56
#
#   location
# 0      NaN
# 1      NaN

# %% [markdown]
# # 🧰 Data utils
#
# ## Summary
#
# We are using torchaudio for audio manipulation, so in case `ffmpeg` is not already installed in your environment, please make sure to install it using `apt-get install ffmpeg`.
#
# Note: Failure to do the above may result in difficulties reading the audio files without converting them to other formats e.g. `.wav` `.flac` `.mp3` etc...

# %% [markdown]
# ## Datasets
#
# Dataset class that can be used for `train`, `dev`, and `test` samples

# %%
osp.join(cfg.paths.data_path, f"{train.iloc[1].audio_path}")
# Out:
# '/kaggle/input/kinasr2025-track-a-melspec/track_A_audio/audio/1738827604-9Q9RG8PhUva4tKnFqMCjM7796NG3'

# %%
import torchaudio
print(torchaudio.list_audio_backends())     # e.g. ['sox_io', 'soundfile']
print(torchaudio.get_audio_backend())       # current backend
# Out:
# ['ffmpeg', 'soundfile']
# None

# %%
torchaudio.load(osp.join(cfg.paths.data_path, f"{train.iloc[1].audio_path}"),backend='ffmpeg') #info = torchaudio.info(audio_path)
# Out:
# (tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -9.0367e-09,
#           -7.7915e-09, -6.6163e-09]]),
#  48000)

# %%
item_path = osp.join(cfg.paths.features_path, f"train/{train.iloc[1].id}.npz")
item = np.load(item_path)

# %%
item['mel_spec'].shape
# Out:
# (128, 106)

# %%
item
# Out:
# NpzFile '/kaggle/input/kinasr2025-track-a-melspec/preprocessed_track_a/preprocessed/features/train/K0sLwAQgpkcHQl2F5obe.npz' with keys: label, mel_spec

# %%
class SpeechDataset(Dataset):
    def __init__(
            self, 
            subset:str, 
            max_label_len:int=cfg.max_len,
            data_pct:float=0.,
            transform=None
        ):
        self.subset = subset
        self.transform = transform
        self.df = pd.read_csv(osp.join(cfg.paths.preprocessed_path, f"{subset}.csv"))
        if data_pct > 0.:
            self.df = self.df.sample(frac=data_pct / 100.0, random_state=cfg.seed)
        self.tokenizer = CharTokenizer()
        self.max_label_len = max_label_len

    def __len__(self):
        return self.df.shape[0]

    def __getitem__(self, idx):
        item_path = osp.join(cfg.paths.features_path, f"{self.subset}/{self.df.iloc[idx].id}.npz")
        item = np.load(item_path)
        audio_input = torch.tensor(item["mel_spec"], dtype=torch.float32)
        waveform, _ = torchaudio.load(osp.join(cfg.paths.data_path, f"{self.df.iloc[idx].audio_path}"))
        waveform = waveform.squeeze(0).to(torch.float32)

        if self.transform:
            audio_input = self.transform(audio_input)
            
        if self.subset in ["train", "dev_test", "valid"]:
            transcript = self.df.iloc[idx].transcription
            label = item["label"].item() if isinstance(item["label"], np.ndarray) else item["label"]
            tokens = self.tokenizer.encode(label, max_len=self.max_label_len)
        
            return waveform, audio_input, torch.tensor(tokens, dtype=torch.long), transcript
        else:
            return waveform, audio_input

# %%
ds = SpeechDataset(subset="dev_test")
waveform, x, tgt, transcript = ds[0]

x.shape, tgt.shape, transcript

# %% [markdown]
# ## Data module
#
# A data module makes it easier to further run experiments using pytorch lightning.

# %%
def pad_batch_tensors(
        tensor_list:list, 
        pad_value:int
    ):
    """
    Function to pad a batch of tensors to the same size along the last dimension.

    Args:
        tensor_list (list of torch.Tensor): List of tensors with varying lengths.
        pad_value (int, optional): Value to use for padding. Default is 0.

    Returns:
        torch.Tensor: Padded batch tensor.
    """
    if len(tensor_list) == 0:
        raise ValueError("Input tensor list is empty.")

    max_length = max(tensor.shape[-1] for tensor in tensor_list)
        
    base_shape = list(tensor_list[0].shape[:-1])  # Keeps all dimensions except the last one
    padded_tensors = torch.full([len(tensor_list)] + base_shape + [max_length], pad_value, dtype=torch.float)

    for i, tensor in enumerate(tensor_list):
        padded_tensors[i, ..., :tensor.shape[-1]] = tensor

    return padded_tensors

def collate_fn(batch):
    waveform_batch, input_batch, target_batch, transcripts = zip(*batch)

    # pad tensors
    waveform_batch = pad_batch_tensors(waveform_batch, pad_value=0)
    input_batch = pad_batch_tensors(input_batch, pad_value=0)
    target_batch = pad_batch_tensors(target_batch, pad_value=0)
    
    return waveform_batch, input_batch, target_batch, transcripts

def test_collate_fn(batch):
    waveform_batch, input_batch = zip(*batch)

    # pad tensors
    waveform_batch = pad_batch_tensors(waveform_batch, pad_value=0)
    input_batch = pad_batch_tensors(input_batch, pad_value=0)
    
    return waveform_batch, input_batch

# %%
class SpeechDataModule(pl.LightningDataModule):
    def __init__(
        self, 
        train_df:pd.DataFrame, 
        dev_df:pd.DataFrame, 
        batch_size:int=cfg.training.batch_size, 
        num_workers:int=cfg.num_workers, 
        max_label_len:int=cfg.max_len,
        data_pct=cfg.data_pct
    ):
        super().__init__()
        self.train_df = train_df
        self.dev_df = dev_df
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.max_label_len = max_label_len
        self.data_pct = data_pct

    def setup(self, stage=None):
        self.train_set = SpeechDataset("train", data_pct=self.data_pct)
        self.dev_set = SpeechDataset("dev_test")
        self.test_set = SpeechDataset("test")
        
        num_val_samples = len(self.dev_set)
        num_train_samples = len(self.train_set)
        num_test_samples = len(self.test_set)
        
        print(f"> # Training samples: {num_train_samples}")
        print(f"> # Validation samples: {num_val_samples}")
        print(f"> # Test samples: {num_test_samples}")
        
    def train_dataloader(self):
        return DataLoader(
            self.train_set, 
            batch_size=self.batch_size, 
            shuffle=True,
            num_workers=self.num_workers, 
            pin_memory=True,
            collate_fn=collate_fn
        )

    def val_dataloader(self):
        return DataLoader(
            self.dev_set, 
            batch_size=self.batch_size, 
            shuffle=False,
            num_workers=self.num_workers, 
            pin_memory=True,
            collate_fn=collate_fn
        )

    def test_dataloader(self):
        return DataLoader(
            self.test_set, 
            batch_size=self.batch_size, 
            shuffle=False,
            num_workers=self.num_workers, 
            pin_memory=True,
            collate_fn=test_collate_fn
        )

# %% [markdown]
# # 👨🏾‍🔬 Test Data modules

# %%
dm = SpeechDataModule(train_df=train, dev_df=dev)
dm.setup()

# %%
train_waveform_batch, train_batch_inp, train_batch_tgt, batch_transcripts = next(iter(dm.train_dataloader()))

train_waveform_batch.shape, train_batch_inp.shape, train_batch_tgt.shape

# %%
dev_waveform_batch, dev_batch_inp, dev_batch_tgt, dev_batch_transcripts = next(iter(dm.val_dataloader()))

dev_waveform_batch.shape, dev_batch_inp.shape, dev_batch_tgt.shape

# %% [markdown]
# # 🕵🏾 EDA + Data (batch) visualization

# %%
def visualize_statistics(df, numeric_cols: list, categorical_cols: list):
    """
    Visualizes numeric data distributions (histograms, box plots, scatter plots) and categorical distributions (bar plots).
    
    Args:
    df (pd.DataFrame): The dataset.
    numeric_cols (list): List of numeric columns (e.g., sentence_length, duration).
    categorical_cols (list): List of categorical columns (e.g., gender, recording_lang).
    """

    num_numeric = len(numeric_cols)
    num_categorical = len(categorical_cols)

    fig, axes = plt.subplots(1, num_numeric, figsize=(5 * num_numeric, 6))
    
    for i, col in enumerate(numeric_cols):
        sns.histplot(df[col], bins=30, kde=True, ax=axes[i], color="blue")
        axes[i].set_title(f"{col} Distribution")
        axes[i].set_xlabel(col)
        axes[i].set_ylabel("Frequency")

        # sns.boxplot(y=df[col], ax=axes[1, i], color="red")
        # axes[1, i].set_title(f"{col} Box Plot")

    plt.tight_layout()
    plt.show()

    if num_categorical > 0:
        fig, axes = plt.subplots(1, num_categorical, figsize=(5 * num_categorical, 3))
    
        if num_categorical == 1:
            axes = [axes]  # Ensure axes is iterable for single column

        for i, col in enumerate(categorical_cols):
            top_categories = df[col].value_counts().nlargest(10)
            sns.barplot(x=top_categories.values, y=top_categories.index, ax=axes[i], color="green")
            axes[i].set_title(f"Top {col} Categories")
            axes[i].set_xlabel("Count")
            axes[i].set_ylabel(col)

        plt.tight_layout()
        plt.show()
    

    if len(numeric_cols) > 1:
        fig, axes = plt.subplots(1, len(numeric_cols) - 1, figsize=(5 * (len(numeric_cols) - 1), 5))
        
        if len(numeric_cols) == 2:
            axes = [axes]  # Ensure axes is iterable for only one scatter plot
        
        for i in range(1, len(numeric_cols)):
            sns.scatterplot(x=df[numeric_cols[i - 1]], y=df[numeric_cols[-1]], ax=axes[i - 1], color="purple", alpha=0.5)
            axes[i - 1].set_title(f"{numeric_cols[i-1]} vs. {numeric_cols[-1]}")
            axes[i - 1].set_xlabel(numeric_cols[i-1])
            axes[i - 1].set_ylabel(numeric_cols[-1])

        plt.tight_layout()
        plt.show()

def plot_random_waveforms(
        df, 
        audio_col: str, 
        text_col: str, 
        translation_col:str,
        audio_dir: str, 
        num_files: int = 2
    ):
    """
    Plots waveforms and plays audio from random samples in a DataFrame, displaying their transcriptions.

    Args:
    df (pd.DataFrame): The DataFrame containing audio file names and transcriptions.
    audio_col (str): Column name containing the audio file names.
    text_col (str): Column name containing transcriptions.
    audio_dir (str): Directory where the audio files are stored.
    num_files (int): Number of random files to display.
    """
    # Select random rows
    selected_rows = df.sample(n=min(num_files, len(df)))

    # Determine the number of rows needed for a 2-column layout
    num_cols = 2
    num_rows = math.ceil(len(selected_rows) / num_cols)

    # Create subplots (2-column layout)
    fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, num_rows * 2))
    axes = axes.flatten()  # Flatten in case of single-row subplots

    # Fill extra empty subplots if needed
    for i in range(len(selected_rows), len(axes)):
        fig.delaxes(axes[i])

    audio_players = []
    for ax, (_, row) in zip(axes, selected_rows.iterrows()):
        file_name = row[audio_col]
        transcription = row[text_col]
        if translation_col:
            translation = row[translation_col]
        file_path = os.path.join(audio_dir, file_name)

        # Load audio
        try:
            waveform, sample_rate = torchaudio.load(file_path)
            waveform = waveform.mean(dim=0)  # Convert to mono if stereo

            # Plot waveform
            ax.plot(torch.arange(waveform.shape[0]) / sample_rate, waveform.numpy(), color="blue")
            ax.set_title(f'File: {file_name} ({waveform.shape[0] / sample_rate:.2f} sec)')
            ax.set_xlabel("Time (seconds)")
            ax.set_ylabel("Amplitude")

            # Store audio player and transcription for later display
            audio_players.append((file_name, ipd.Audio(waveform.numpy(), rate=sample_rate), transcription))
        except Exception as e:
            print(f"Error loading {file_name}: {e}")

    plt.tight_layout()
    plt.show()

    # Display audio playback and transcriptions
    for file_name, player, transcription in audio_players:
        print(f"🔊 Playing: {file_name}")
        display(player)
        print(f"📝 Transcription: {transcription}\n")
        if translation_col:
            print(f"📝EN Translation: {translation}\n")
        print()

# %%
train.describe().transpose()

# %% [markdown]
# ### 📊 Taining stats

# %%
num_cols = ['sentence_length', 'num_tokens', 'age_group', 'duration']
cat_cols = ['project_name', 'location', 'image_category', 'image_sub_category', 'gender']

visualize_statistics(df=train, numeric_cols=num_cols, categorical_cols=cat_cols)

# %% [markdown]
# ### 📊 Validation Stats

# %%
dev.describe().transpose()

# %%
visualize_statistics(df=dev, numeric_cols=num_cols, categorical_cols=cat_cols)

# %% [markdown]
# ### 📊 Test Stats

# %%
test.describe().transpose()

# %%
num_cols = ['age_group', 'duration']
cat_cols = ['location', 'image_category', 'image_sub_category', 'gender']

visualize_statistics(df=test, numeric_cols=num_cols, categorical_cols=cat_cols)

# %%
num_short_audios = train[train["duration"] <10].shape[0]
num_avg_audios = train[(train["duration"] >=10) & (train["duration"] <=30)].shape[0]
num_long_audios = train[train["duration"] >30].shape[0]

pct_short = 100*num_short_audios / train.shape[0]
pct_avg = 100*num_avg_audios / train.shape[0]
pct_long = 100*num_long_audios / train.shape[0]

print(f"# short audio samples: \t{num_short_audios} ({pct_short:.2f}%)")
print(f"# avg audio samples: \t{num_avg_audios} ({pct_avg:.2f}%)")
print(f"# long audio samples: \t{num_long_audios} ({pct_long:.2f}%)")

# %%
num_short_audios = dev[dev["duration"] <10].shape[0]
num_avg_audios = dev[(dev["duration"] >=10) & (dev["duration"] <=30)].shape[0]
num_long_audios = dev[dev["duration"] >30].shape[0]

pct_short = 100*num_short_audios / dev.shape[0]
pct_avg = 100*num_avg_audios / dev.shape[0]
pct_long = 100*num_long_audios / dev.shape[0]

print(f"# short audio samples: \t{num_short_audios} ({pct_short:.2f}%)")
print(f"# avg audio samples: \t{num_avg_audios} ({pct_avg:.2f}%)")
print(f"# long audio samples: \t{num_long_audios} ({pct_long:.2f}%)")

# %%
num_short_audios = test[test["duration"] <10].shape[0]
num_avg_audios = test[(test["duration"] >=10) & (test["duration"] <=30)].shape[0]
num_long_audios = test[test["duration"] >30].shape[0]

pct_short = 100*num_short_audios / test.shape[0]
pct_avg = 100*num_avg_audios / test.shape[0]
pct_long = 100*num_long_audios / test.shape[0]

print(f"# short audio samples: \t{num_short_audios} ({pct_short:.2f}%)")
print(f"# avg audio samples: \t{num_avg_audios} ({pct_avg:.2f}%)")
print(f"# long audio samples: \t{num_long_audios} ({pct_long:.2f}%)")

# %% [markdown]
# By focusing on audio samples with durations between `10s` and `30s`, we retain more than `99%` of the original datasets; this is quite enough for initial experiments or even the entire challenge.

# %% [markdown]
# ### 🗄️ Batch inspection

# %%
def visualize_batch(
    data_module, 
    n_samples=cfg.training.batch_size, 
    loader:str="train"
   ):
    """
    Visualizes a batch of speech data: spectrograms and corresponding transcripts.

    Args:
        data_module (SpeechDataModule): The data module for loading batches.
        n_samples (int): Number of samples to visualize.
        loader (str) : One of "train", "test", or "dev"
    """
    # Load the data
    dataloaders = {
        "train": data_module.train_dataloader(),
        "dev": data_module.val_dataloader(),
        "test": data_module.test_dataloader()
    }
    assert loader in ["train", "test", "dev"], "visualization `loader` only supports 'train', 'test', or 'dev' as values."
    dl = dataloaders[loader]
    wavforms, inputs, targets, transcripts = next(iter(dl))

    # Extract data
    wavforms = wavforms[:n_samples] 
    inputs = inputs[:n_samples] 
    targets = targets[:n_samples] 
    transcripts = transcripts[:n_samples]

    # Plot data
    fig, axes = plt.subplots(n_samples, 2, figsize=(10, n_samples * 2), constrained_layout=True)

    for i in range(n_samples):
        inp = axes[i, 0].imshow(inputs[i].numpy(), aspect="auto", origin="lower", cmap="magma")
        axes[i, 0].set_title(f"Transcript - {transcripts[i][:64]}...", fontsize=8)
        axes[i, 0].set_xlabel("Time")
        axes[i, 0].set_ylabel("Frequency")
        fig.colorbar(inp, ax=axes[i, 0], orientation="vertical", fraction=0.05, pad=0.05)
        
        wav = wavforms[i]
        axes[i, 1].plot(torch.arange(wav.shape[0]) / cfg.spec_params.sr, wav.numpy(), color="blue")
        axes[i, 1].set_title(f"Transcript - {transcripts[i][:64]}...", fontsize=8)
        axes[i, 1].set_xlabel("Time (seconds)")
        axes[i, 1].set_ylabel("Amplitude")
        
    # plt.tight_layout()
    plt.show()

# %%
# %%time
visualize_batch(data_module=dm, n_samples=2, loader="train")

# %%
# %%time
visualize_batch(data_module=dm, n_samples=2, loader="dev")

# %% [markdown]
# Note: The visualization seems to take a bit longer in kaggle kernels. You should be aware of how this might affect your data loading pipeline.

# %%
test_ds = SpeechDataset(subset="test")
test_wav, test_inp = test_ds[0]

test_wav.shape, test_inp.shape

# %%
test_batch_wav, test_batch_inp = next(iter(dm.test_dataloader()))
test_batch_wav.shape, test_batch_inp.shape

# %% [markdown]
# # 🏁 Conclusion
#
# You have reached the end of this tutorial.
#
# 🤗 In addition to being an interesting competition, this challenge is a great way to demonstrate our local expertise in adressing our own gaps and try to bridge the current digital divide.
#
# If you enjoyed this notebook, please give it an upvote and leave a comment so that other people can find it too! 🥺
#
# 🎉 Best of luck Kaggling...Murakoze Cyaaaane!
